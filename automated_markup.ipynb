# %%
# Import a module for regular expression

import re
import pandas as pd

# %%
# Just demonstrate how the TSV file to be converted into the TEI-compliant file looks like
dataframe = pd.read_table('Ward_ledger_HMS_all.tsv')
dataframe
# Out:
#     PageNum                  Head    Place        Date  \
# 0        3A                 Comus   Barrow  1934-08-01
# 1       NaN                   NaN      NaN  1934-08-30
# 2       NaN                   NaN      NaN  1934-08-30
# 3       NaN                   NaN      NaN  1934-08-30
# 4       NaN                   NaN      NaN  1934-09-05
# 5       NaN                   NaN      NaN  1934-09-09
# 6       NaN                   NaN      NaN  1934-09-15
# 7       NaN                   NaN      NaN  1934-09-05
# 8       NaN                   NaN      NaN  1934-09-09
# 9       NaN                   NaN      NaN  1934-10-04
# 10      NaN                   NaN      NaN  1934-12-05
# 11      NaN                   NaN      NaN  1935-02-06
# 12      NaN                   NaN      NaN  1935-04-08
# 13      NaN                   NaN      NaN  1934-07-18
# 14      NaN                   NaN      NaN  1934-09-09
# 15      NaN                   NaN      NaN  1934-09-11
# 16      NaN                   NaN      NaN  1935-05-30
# 17      NaN                   NaN      NaN  1934-09-30
# 18      NaN                   NaN      NaN  1934-09-09
# 19      NaN                   NaN      NaN  1934-09-09
# 20      NaN                   NaN      NaN  1934-09-10
# 21      NaN                   NaN      NaN  1935-03-06
# 22      NaN                   NaN      NaN  1935-03-06
# 23      NaN                   NaN      NaN  1935-07-06
# 24      NaN                   NaN      NaN  1935-07-31
# 25       17             Carstairs    Grays  1935-05-15
# 26      NaN                   NaN      NaN  1935-05-16
# 27      NaN                   NaN      NaN  1935-05-16
# 28      NaN                   NaN      NaN  1935-05-02
# 29      NaN                   NaN      NaN  1935-05-02
# ..      ...                   ...      ...         ...
# 620     NaN                   NaN      NaN  1939-01-05
# 621     NaN                   NaN      NaN  1938-12-14
# 622     NaN                   NaN      NaN  1939-01-04
# 623     NaN                   NaN      NaN  1939-01-11
# 624     NaN                   NaN      NaN  1939-01-11
# 625     149     Admiralty Lighter   Barrow  1941-03-28
# 626     NaN                   NaN      NaN  1941-03-31
# 627     NaN                   NaN      NaN  1941-04-18
# 628     NaN                   NaN      NaN  1941-05-15
# 629     NaN                   NaN      NaN  1941-06-11
# 630     NaN                   NaN      NaN  1941-07-16
# 631     158  G. 13 (Torpedo Boat)  Preston  1942-12-03
# 632     NaN                   NaN      NaN  1943-02-11
# 633     NaN                   NaN      NaN  1943-02-23
# 634     NaN                   NaN      NaN  1943-01-28
# 635     NaN                   NaN      NaN  1943-02-22
# 636     NaN                   NaN      NaN  1943-02-19
# 637     NaN                   NaN      NaN  1943-02-18
# 638     NaN                   NaN      NaN  1943-05-03
# 639     NaN                   NaN      NaN  1943-06-11
# 640     NaN                   NaN      NaN  1943-07-07
# 641    158A  G. 15 (Torpedo Boat)  Preston  1942-12-03
# 642     NaN                   NaN      NaN  1943-02-11
# 643     NaN                   NaN      NaN  1943-02-23
# 644     NaN                   NaN      NaN  1943-01-28
# 645     NaN                   NaN      NaN  1943-02-22
# 646     NaN                   NaN      NaN  1943-02-21
# 647     NaN                   NaN      NaN  1943-05-03
# 648     NaN                   NaN      NaN  1943-06-11
# 649     NaN                   NaN      NaN  1943-07-07
#
#                                          Name  \
# 0                          Leslie & Godwin Ld
# 1                          Leslie & Godwin Ld
# 2                          Leslie & Godwin Ld
# 3                          Leslie & Godwin Ld
# 4                         United Towing Co Ld
# 5                               Trinity House
# 6                            Customs & Excise
# 7                               Trinity House
# 8                                  LM & S Rly
# 9                                  LM & S Rly
# 10                         Leslie & Godwin Ld
# 11                         Leslie & Godwin Ld
# 12                         Leslie & Godwin Ld
# 13                                     Lelant
# 14                                     RWSole
# 15                      ARStenhouse & Partner
# 16                         Leslie & Godwin Ld
# 17                                Bulk Travel
# 18                                 LM & S Rly
# 19                                    R Crane
# 20                                 GRCharnley
# 21                                 GRCharnley
# 22                                    R Crane
# 23                         Leslie & Godwin Ld
# 24                         Leslie & Godwin Ld
# 25                        United Towing Co Ld
# 26                      ARStenhouse & Partner
# 27                      ARStenhouse & Partner
# 28                         Leslie & Godwin Ld
# 29                         Leslie & Godwin Ld
# ..                                        ...
# 620                        Leslie & Godwin Ld
# 621                        Leslie & Godwin Ld
# 622                         Grays Wharf Depot
# 623                         Grays Wharf Depot
# 624                         Grays Wharf Depot
# 625                               S. Charnley
# 626                        Leslie & Godwin Ld
# 627                        Leslie & Godwin Ld
# 628                        Leslie & Godwin Ld
# 629                        Leslie & Godwin Ld
# 630                        Leslie & Godwin Ld
# 631                        Leslie & Godwin Ld
# 632  Paymaster, Royal Netherland Navy, London
# 633                     R. Gardner, Lancaster
# 634                            LMSRailway Co.
# 635                         Ribble Navigation
# 636                    Trinity House Pilotage
# 637                        Leslie & Godwin Ld
# 638                        Leslie & Godwin Ld
# 639                        Leslie & Godwin Ld
# 640                        Leslie & Godwin Ld
# 641                        Leslie & Godwin Ld
# 642  Paymaster, Royal Netherland Navy, London
# 643                     R. Gardner, Lancaster
# 644                            LMSRailway Co.
# 645                         Ribble Navigation
# 646                    Trinity House Pilotage
# 647                        Leslie & Godwin Ld
# 648                        Leslie & Godwin Ld
# 649                        Leslie & Godwin Ld
#
#                                                Service  Ref  Pound  Silling  \
# 0                         Insurance for 1 month L12500  NaN    4.0     14.0
# 1    Insurance to Devonport to Barrow for 3 months ...  NaN  149.0     15.0
# 2                     Insurance under Collision Clause  NaN    4.0     15.0
# 3                        Insurance on Anchors & Cables  NaN    NaN     10.0
# 4                      Towage to Barrow per Tug Seaman  NaN  345.0      NaN
# 5                                      Inward Pilotage  NaN    8.0     13.0
# 6                                Walney Dues 1312 Tons  NaN    5.0      9.0
# 7                                     Outward Pilotage  NaN    2.0     16.0
# 8                                 Towage Basin to Dock  NaN   15.0      NaN
# 9                  Carriage on Lamps sold to Devonport  NaN    NaN     15.0
# 10                       Insurance for 2 months L10000  NaN    7.0     10.0
# 11                        Insurance for 2 months L9000  NaN    6.0     15.0
# 12                        Insurance for 2 months L7000  NaN    5.0      5.0
# 13                                 Inspecting expenses  NaN    NaN     16.0
# 14                                           Run money  NaN   59.0      9.0
# 15                                Insurance on runners  NaN    3.0      3.0
# 16                         Insurance for 1 month L6000  NaN    2.0      5.0
# 17                           Vouchers used for runners  NaN   11.0      6.0
# 18                            Towage Bar Buoy to Basin  NaN   13.0      3.0
# 19                                          Attendance  NaN    1.0     10.0
# 20                                       Dock Pilotage  NaN    1.0      2.0
# 21                            Dock Pilotage to Channel  NaN    2.0      8.0
# 22                                          Attendance  NaN    1.0     10.0
# 23                         Insurance for 1 month L2000  NaN    NaN     15.0
# 24                         Insurance for 1 month L1000  NaN    NaN      7.0
# 25          Towage Sheerness to Grays per Tug Irishman  NaN   30.0      NaN
# 26                                Insurance on runners  NaN    1.0     15.0
# 27                                Insurance on runners  NaN    4.0      9.0
# 28   Insurance Sheerness to Grays & 3 months on Hul...  NaN    1.0     19.0
# 29                    Insurance under Collision Clause  NaN    NaN      2.0
# ..                                                 ...  ...    ...      ...
# 620  Insurance Sheerness in tow to Grays & 3 months...  NaN    NaN      2.0
# 621                    Insurance on runners & watchmen  NaN    1.0      4.0
# 622                                         Inspecting  NaN    NaN     17.0
# 623                             Preparing at Sheerness  NaN    1.0      9.0
# 624                                       Run to Grays  NaN    5.0      2.0
# 625               Assistance (Boating) to Channel Wall  NaN    NaN     15.0
# 626                  Insurance for 1 month on HM L1100  NaN    NaN     15.0
# 627                  Insurance for 1 month on HM L1100  NaN    NaN     15.0
# 628                  Insurance for 1 month on HM L1100  NaN    NaN     15.0
# 629                   Insurance for 1 month on HM L800  NaN    NaN     11.0
# 630                   Insurance for 1 month on HM L250  NaN    NaN      3.0
# 631                  Insurance for 3 months on HM L600  NaN    2.0     17.0
# 632    Refund of Dock rental paid on Torpedo boats G13  NaN    3.0      9.0
# 633                                           Pilotage  NaN    4.0     15.0
# 634                          Storage on Canal --- Dock  NaN    3.0      2.0
# 635                      Use of Tugs --- Dk to Preston  NaN   75.0      NaN
# 636                   Pilotage from sea to Dand's Grid  NaN    2.0     12.0
# 637             Premium (Additional) --- Dk to Preston  NaN    1.0      NaN
# 638                   Insurance for 1 month on HM L600  NaN    NaN      8.0
# 639                   Insurance for 1 month on HM L500  NaN    NaN      6.0
# 640                   Insurance for 1 month on HM L200  NaN    NaN      2.0
# 641                  Insurance for 3 months on HM L600  NaN    2.0     17.0
# 642    Refund of Dock rental paid on Torpedo boats G15  NaN    3.0      9.0
# 643                                           Pilotage  NaN    4.0     15.0
# 644                          Storage on Canal --- Dock  NaN    3.0      2.0
# 645                      Use of Tugs --- Dk to Preston  NaN   75.0      NaN
# 646                          Pilotage from sea to quay  NaN    2.0     12.0
# 647                   Insurance for 1 month on HM L600  NaN    NaN      8.0
# 648                   Insurance for 1 month on HM L500  NaN    NaN      6.0
# 649                   Insurance for 1 month on HM L400  NaN    NaN      5.0
#
#      Pence
# 0      5.0
# 1      3.0
# 2      7.0
# 3      6.0
# 4      NaN
# 5      3.0
# 6      4.0
# 7      NaN
# 8      NaN
# 9      4.0
# 10    11.0
# 11    10.0
# 12     8.0
# 13     3.0
# 14     4.0
# 15     2.0
# 16     4.0
# 17     6.0
# 18     2.0
# 19     NaN
# 20     6.0
# 21     9.0
# 22     NaN
# 23     2.0
# 24     8.0
# 25     NaN
# 26     7.0
# 27     6.0
# 28     1.0
# 29     3.0
# ..     ...
# 620    7.0
# 621    6.0
# 622    8.0
# 623    7.0
# 624    NaN
# 625    NaN
# 626    NaN
# 627    1.0
# 628    1.0
# 629    NaN
# 630    6.0
# 631    4.0
# 632    2.0
# 633    NaN
# 634    6.0
# 635    NaN
# 636    NaN
# 637    5.0
# 638    2.0
# 639   19.0
# 640    9.0
# 641    4.0
# 642    3.0
# 643    NaN
# 644    6.0
# 645    NaN
# 646    NaN
# 647    3.0
# 648   10.0
# 649    6.0
#
# [650 rows x 10 columns]

# %%
# Define a function to automatically mark up the TSV file in conformity with the TEI

def generate_DEPCHA_TEI_from_TSV(input_file, output_file):

    file = open(input_file, 'r', encoding='utf-8')
    lines = file.readlines()
    file.close()

    output_f = open(output_file, 'w', encoding='utf-8')
    n = '\n'
    output_f.write("""<?xml version="1.0" encoding="UTF-8"?>
<?xml-model href="http://www.tei-c.org/release/xml/tei/custom/schema/relaxng/tei_all.rng" type="application/xml" schematypens="http://relaxng.org/ns/structure/1.0"?>
<?xml-model href="http://www.tei-c.org/release/xml/tei/custom/schema/relaxng/tei_all.rng" type="application/xml"
	schematypens="http://purl.oclc.org/dsdl/schematron"?>
<TEI xmlns="http://www.tei-c.org/ns/1.0">
      <teiHeader>
            <fileDesc>
                  <titleStmt>
                        <title>Title</title>
                  </titleStmt>
                  <publicationStmt>
                        <publisher>KCL MADH</publisher>
                        <idno type="PID">o:depcha.ward_ledger.1</idno>
                        <availability>
                              <p/>
                        </availability>
                        <date when="2019-05-25">May 25, 2019</date>
                  </publicationStmt>
                  <sourceDesc>
                        <p>Accounts of <orgName ana="#bk_from" ref="ThosWardLtd">Thos W. Ward Ltd</orgName> from <date ana="#bk_when"
                                    when="1934-06-01">June 1934</date>. 
                        </p>
                  </sourceDesc>
            </fileDesc>
      </teiHeader>
      <text>
            <body>""")

    noise = re.compile('&amp;| |,')
    pageNum_check = '0'

    for index, line in enumerate(lines):
        if index == 0:
            pass
        else:
            line = line.rstrip()
            cols = line.split('\t')
            pageNum = cols[0]
            head = cols[1]
            place = cols[2]
            date = cols[3]
            if '/' in date:
                date = date[:-3]
            firm_name = cols[4].replace('&', '&amp;')

            # create a reference name for each firm by manipulating the string
            firm_ref = re.sub(noise, '', firm_name)
            firm_ref = '#' + firm_ref
        
            service = cols[5].replace('&', '&amp;')
            service_split = service.split(' ')
            commodity = service_split[0]
            commodity = re.sub(noise, '', commodity)

            try:
                ref = cols[6]
            except IndexError:
                ref = ""
            try:
                pound = cols[7]
            except IndexError:
                pound = ""
            try:
                shilling = cols[8]
            except IndexError:
                shilling = ""
            try:
                pence = cols[9]
            except IndexError:
                pence = ""
        
            if pageNum != "":
                if index != 1:
                    output_f.write(f'</table></div></div>{n}')
                output_f.write(f'<div><fw type="pageNum">{pageNum}</fw>{n}')
                output_f.write(f'<div><table><head>{head}<placeName>{place}</placeName></head>{n}')
        
            output_f.write(f'<row ana="#bk_entry"><cell><date ana="#bk_when" when="{date}"/></cell>{n}')
            output_f.write(f'<cell><name ana="#bk_to" ref="{firm_ref}">{firm_name}</name>{n}')
            output_f.write(f'<measure ana="#bk_service #bk_to" commodity="{commodity}">{service}</measure></cell>{n}')
            output_f.write(f'<cell><rs>{ref}</rs></cell>{n}')
            if pound != "":
                output_f.write(f'<cell><measure ana="#bk_money #bk_from" commodity="Currency" quantity="{pound}" unit="pound">{pound}</measure></cell>{n}')
            if shilling != "":
                output_f.write(f'<cell><measure ana="#bk_money #bk_from" commodity="Currency" quantity="{shilling}" unit="shilling">{shilling}</measure></cell>{n}')
            if pence != "":
                output_f.write(f'<cell><measure ana="#bk_money #bk_from" commodity="Currency" quantity="{pence}" unit="pence">{pence}</measure></cell>{n}')
            output_f.write('</row>')

    output_f.write('</table></div></div></body></text></TEI>')
    output_f.close()

# %%
# Execute!

generate_DEPCHA_TEI_from_TSV('Ward_ledger_HMS_all.tsv', 'Ward_ledger_HMS_all.xml')
